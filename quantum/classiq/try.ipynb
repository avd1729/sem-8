# %%
# !pip install classiq==0.70.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: classiq==0.70.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (0.70.0)
# Requirement already satisfied: ConfigArgParse<2.0.0,>=1.5.3 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (1.7)
# Requirement already satisfied: Pyomo<6.6,>=6.5 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (6.5.0)
# Requirement already satisfied: black<25.0,>=24.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (24.10.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (0.28.1)
# Requirement already satisfied: keyring<24.0.0,>=23.5.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (23.13.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.4.3 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (3.10.0)
# Requirement already satisfied: networkx<3.0.0,>=2.5.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (2.8.8)
# Requirement already satisfied: numexpr<3.0.0,>=2.7.3 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (2.10.2)
# Requirement already satisfied: numpy<2.0.0,>=1.20.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (1.26.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (23.2)
# Requirement already satisfied: pandas<3.0.0,>=1.4.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (2.2.3)
# Requirement already satisfied: plotly<6.0.0,>=5.7.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (5.24.1)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (2.9.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (2.8.1)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (1.14.1)
# Requirement already satisfied: sympy<2.0.0,>=1.13.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (1.13.1)
# Requirement already satisfied: tabulate<1,>=0.8.9 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (0.9.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.67.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from classiq==0.70.0) (4.67.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from black<25.0,>=24.0->classiq==0.70.0) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\aravind\college\quantum\venv\lib\site-packages (from black<25.0,>=24.0->classiq==0.70.0) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from black<25.0,>=24.0->classiq==0.70.0) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\aravind\college\quantum\venv\lib\site-packages (from black<25.0,>=24.0->classiq==0.70.0) (4.3.6)
# Requirement already satisfied: anyio in c:\users\aravind\college\quantum\venv\lib\site-packages (from httpx<1,>=0.23.0->classiq==0.70.0) (4.7.0)
# Requirement already satisfied: certifi in c:\users\aravind\college\quantum\venv\lib\site-packages (from httpx<1,>=0.23.0->classiq==0.70.0) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\users\aravind\college\quantum\venv\lib\site-packages (from httpx<1,>=0.23.0->classiq==0.70.0) (1.0.7)
# Requirement already satisfied: idna in c:\users\aravind\college\quantum\venv\lib\site-packages (from httpx<1,>=0.23.0->classiq==0.70.0) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\aravind\college\quantum\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->classiq==0.70.0) (0.14.0)
# Requirement already satisfied: jaraco.classes in c:\users\aravind\college\quantum\venv\lib\site-packages (from keyring<24.0.0,>=23.5.0->classiq==0.70.0) (3.4.0)
# Requirement already satisfied: importlib-metadata>=4.11.4 in c:\users\aravind\college\quantum\venv\lib\site-packages (from keyring<24.0.0,>=23.5.0->classiq==0.70.0) (8.6.1)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from keyring<24.0.0,>=23.5.0->classiq==0.70.0) (0.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aravind\college\quantum\venv\lib\site-packages (from matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from pandas<3.0.0,>=1.4.0->classiq==0.70.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aravind\college\quantum\venv\lib\site-packages (from pandas<3.0.0,>=1.4.0->classiq==0.70.0) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from plotly<6.0.0,>=5.7.0->classiq==0.70.0) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from pydantic<2.10.0,>=2.9.0->classiq==0.70.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\aravind\college\quantum\venv\lib\site-packages (from pydantic<2.10.0,>=2.9.0->classiq==0.70.0) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from pydantic<2.10.0,>=2.9.0->classiq==0.70.0) (4.12.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->classiq==0.70.0) (1.0.1)
# Requirement already satisfied: ply in c:\users\aravind\college\quantum\venv\lib\site-packages (from Pyomo<6.6,>=6.5->classiq==0.70.0) (3.11)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aravind\college\quantum\venv\lib\site-packages (from sympy<2.0.0,>=1.13.0->classiq==0.70.0) (1.3.0)
# Requirement already satisfied: colorama in c:\users\aravind\college\quantum\venv\lib\site-packages (from tqdm<5.0.0,>=4.67.1->classiq==0.70.0) (0.4.6)
# Requirement already satisfied: zipp>=3.20 in c:\users\aravind\college\quantum\venv\lib\site-packages (from importlib-metadata>=4.11.4->keyring<24.0.0,>=23.5.0->classiq==0.70.0) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\aravind\college\quantum\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.4.3->classiq==0.70.0) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aravind\college\quantum\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->classiq==0.70.0) (1.3.1)
# Requirement already satisfied: more-itertools in c:\users\aravind\college\quantum\venv\lib\site-packages (from jaraco.classes->keyring<24.0.0,>=23.5.0->classiq==0.70.0) (10.6.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from classiq import (
    create_model,
    Circuit,
    H,
    X,
    Z,
    Measure
)
import random
import numpy as np

class BB84Protocol:
    def __init__(self, num_qubits=10):
        """
        Initialize BB84 Quantum Key Distribution Protocol
        
        Args:
            num_qubits (int): Number of qubits to transmit
        """
        self.num_qubits = num_qubits
        self.alice_bases = []
        self.alice_bits = []
        self.bob_bases = []
        self.bob_bits = []
        
    def create_bb84_circuit(self):
        """
        Create quantum circuit for BB84 protocol
        
        Returns:
            Quantum circuit
        """
        @create_model
        def bb84_circuit(target_qubits):
            # Generate random bits and bases for Alice
            for i in range(self.num_qubits):
                # Randomly choose bit (0 or 1)
                bit = random.randint(0, 1)
                # Randomly choose measurement basis
                basis = random.choice(['rectilinear', 'diagonal'])
                
                self.alice_bits.append(bit)
                self.alice_bases.append(basis)
                
                # Prepare quantum state based on bit and basis
                if basis == 'rectilinear':
                    # Computational basis (Z basis)
                    if bit == 1:
                        X(target_qubits[i])
                else:
                    # Diagonal basis (X basis)
                    H(target_qubits[i])
                    if bit == 1:
                        Z(target_qubits[i])
            
            # Bob's measurement bases
            bob_bases = [random.choice(['rectilinear', 'diagonal']) for _ in range(self.num_qubits)]
            self.bob_bases = bob_bases
            
            # Bob's measurement
            for i in range(self.num_qubits):
                # Change basis if needed
                if bob_bases[i] == 'diagonal':
                    H(target_qubits[i])
                
                # Measure the qubit
                self.bob_bits.append(Measure(target_qubits[i]))
            
            return target_qubits
        
        return bb84_circuit
    
    def sift_keys(self):
        """
        Sift the keys by comparing bases
        
        Returns:
            Tuple of matching keys for Alice and Bob
        """
        alice_sifted_key = []
        bob_sifted_key = []
        
        for i in range(self.num_qubits):
            if self.alice_bases[i] == self.bob_bases[i]:
                alice_sifted_key.append(self.alice_bits[i])
                bob_sifted_key.append(self.bob_bits[i])
        
        return alice_sifted_key, bob_sifted_key
    
    def run_protocol(self):
        """
        Execute the full BB84 protocol
        
        Returns:
            Tuple of results: (Alice's key, Bob's key, Matching percentage)
        """
        # Prepare the quantum circuit
        bb84_model = self.create_bb84_circuit()
        
        # Sift the keys
        alice_key, bob_key = self.sift_keys()
        
        # Calculate matching percentage
        matching_percentage = sum(a == b for a, b in zip(alice_key, bob_key)) / len(alice_key) * 100 if alice_key else 0
        
        return alice_key, bob_key, matching_percentage

def main():
    # Run BB84 protocol
    protocol = BB84Protocol(num_qubits=20)
    alice_key, bob_key, matching_percentage = protocol.run_protocol()
    
    print("Alice's Bases:", protocol.alice_bases)
    print("Bob's Bases: ", protocol.bob_bases)
    print("\nAlice's Key:", alice_key)
    print("Bob's Key:  ", bob_key)
    print(f"\nKey Matching Percentage: {matching_percentage:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from classiq import (
#       2     create_model,
#       3     Circuit,
#       4     H,
#       5     X,
#       6     Z,
#       7     Measure
#       8 )
#       9 import random
#      10 import numpy as np
#
# ImportError: cannot import name 'Circuit' from 'classiq' (c:\Users\Aravind\college\quantum\venv\Lib\site-packages\classiq\__init__.py)

# %%
import classiq
print(classiq.__version__)
print(dir(classiq))
# Out:
# 0.70.0
# ['Analyzer', 'Array', 'CArray', 'CBool', 'CCX', 'CH', 'CInt', 'CPHASE', 'CRX', 'CRY', 'CRZ', 'CReal', 'CX', 'CY', 'CZ', 'ChemistryAtom', 'CombinatorialOptimizationSolution', 'Constraints', 'ControlState', 'CustomHardwareSettings', 'Element', 'ExecutionParams', 'FermionMapping', 'FinanceFunction', 'FinanceFunctionType', 'FockHamiltonianProblem', 'GaussianModel', 'H', 'I', 'IDENTITY', 'Input', 'LadderOp', 'LadderOperator', 'LadderTerm', 'LogNormalModel', 'Molecule', 'MoleculeProblem', 'OptimizationParameter', 'Optimizer', 'Output', 'PHASE', 'Pauli', 'PauliTerm', 'Position', 'Preferences', 'QArray', 'QBit', 'QCallable', 'QCallableList', 'QConstant', 'QNum', 'QSVMFeatureMapEntanglement', 'QSVMFeatureMapPauli', 'QStruct', 'QsvmResult', 'QuantumProgram', 'R', 'RESET', 'RX', 'RXX', 'RY', 'RYY', 'RZ', 'RZZ', 'RegisterArithmeticInfo', 'RegisterUserInput', 'S', 'SDG', 'SIGNED', 'SWAP', 'T', 'TDG', 'TranspilerBasisGates', 'U', 'UNSIGNED', 'X', 'Y', 'Z', '_single_pauli', 'add', 'allocate', 'allocate_num', 'amplitude_amplification', 'amplitude_estimation', 'analyzer', 'applications', 'apply', 'apply_to_all', 'assign', 'assign_amplitude', 'authenticate', 'batch_estimate', 'batch_sample', 'bind', 'bloch_sphere_feature_map', 'c_modular_multiply', 'cc_modular_add', 'cfunc', 'commuting_paulis_exponent', 'construct_chemistry_model', 'construct_combinatorial_optimization_model', 'construct_finance_model', 'construct_grover_model', 'construct_qsvm_model', 'control', 'create_model', 'encode_in_angle', 'encode_on_bloch', 'estimate', 'exact_amplitude_amplification', 'execute', 'execute_async', 'execution', 'exponentiation_with_depth_constraint', 'fock_hamiltonian_hartree_fock', 'fock_hamiltonian_hva', 'fock_hamiltonian_problem_to_hamiltonian', 'fock_hamiltonian_ucc', 'free', 'full_hea', 'gaussian_finance', 'gaussian_finance_post_process', 'get_expression_numeric_attributes', 'grid_entangler_graph', 'grover_diffuser', 'grover_operator', 'grover_search', 'hadamard_transform', 'hamiltonian_to_matrix', 'hypercube_entangler_graph', 'if_', 'inplace_add', 'inplace_c_modular_multiply', 'inplace_prepare_amplitudes', 'inplace_prepare_int', 'inplace_prepare_state', 'inplace_xor', 'integer_xor', 'invert', 'iqae', 'linear_pauli_rotations', 'log_normal_finance', 'log_normal_finance_post_process', 'matrix_to_hamiltonian', 'modular_add', 'modular_add_constant', 'modular_exp', 'modular_increment', 'molecule_ground_state_solution_post_process', 'molecule_hartree_fock', 'molecule_hva', 'molecule_problem_to_hamiltonian', 'molecule_problem_to_qmod', 'molecule_ucc', 'multiswap', 'open_help', 'pauli_feature_map', 'permute', 'phase', 'phase_oracle', 'power', 'prepare_amplitudes', 'prepare_bell_state', 'prepare_exponential_state', 'prepare_ghz_state', 'prepare_int', 'prepare_state', 'prepare_uniform_interval_state', 'prepare_uniform_trimmed_state', 'projector_controlled_double_phase', 'projector_controlled_phase', 'qae_with_qpe_result_post_processing', 'qaoa_cost_layer', 'qaoa_init', 'qaoa_layer', 'qaoa_mixer_layer', 'qaoa_penalty', 'qct_qst_type1', 'qct_qst_type2', 'qct_type2', 'qdrift', 'qft', 'qft_const_adder_phase', 'qft_no_swap', 'qft_space_add_const', 'qfunc', 'qmod', 'qpe', 'qpe_flexible', 'qst_type2', 'qsvm_full_run', 'qsvt', 'qsvt_inversion', 'qsvt_lcu', 'qsvt_lcu_step', 'qsvt_step', 'quantum_program_from_qasm', 'quantum_program_from_qasm_async', 'randomized_benchmarking', 'real_xor_constant', 'reflect_about_zero', 'repeat', 'sample', 'save', 'set_constraints', 'set_execution_preferences', 'set_preferences', 'set_quantum_program_execution_preferences', 'show', 'single_pauli_exponent', 'span_lookup_table', 'suzuki_trotter', 'suzuki_trotter', 'swap_test', 'switch', 'synthesis', 'synthesize', 'synthesize_async', 'unitary', 'update_constraints', 'update_execution_preferences', 'update_preferences', 'vqe', 'within_apply', 'write_qmod']

# %%
from classiq import (
    create_model,
    QArray,
    QBit,
    H,
    X,
    Z,
    execute,
    synthesize
)
import random
import numpy as np

class BB84Protocol:
    def __init__(self, num_qubits=10):
        """
        Initialize BB84 Quantum Key Distribution Protocol
        
        Args:
            num_qubits (int): Number of qubits to transmit
        """
        self.num_qubits = num_qubits
        self.alice_bases = []
        self.alice_bits = []
        self.bob_bases = []
        self.bob_bits = []
        
    def create_bb84_circuit(self):
        """
        Create quantum circuit for BB84 protocol
        
        Returns:
            Quantum circuit model
        """
        @create_model
        def bb84_circuit(qubits: QArray[QBit]):
            # Reset tracking lists
            self.alice_bases.clear()
            self.alice_bits.clear()
            self.bob_bases.clear()
            self.bob_bits.clear()
            
            # Alice prepares qubits
            for i in range(self.num_qubits):
                # Generate random bit and basis
                bit = random.randint(0, 1)
                basis = random.choice(['rectilinear', 'diagonal'])
                
                self.alice_bits.append(bit)
                self.alice_bases.append(basis)
                
                # Prepare quantum state based on bit and basis
                if basis == 'rectilinear':
                    # Computational basis (Z basis)
                    if bit == 1:
                        X(qubits[i])
                else:
                    # Diagonal basis (X basis)
                    H(qubits[i])
                    if bit == 1:
                        Z(qubits[i])
            
            # Bob's measurement bases
            bob_bases = [random.choice(['rectilinear', 'diagonal']) for _ in range(self.num_qubits)]
            self.bob_bases = bob_bases
            
            # Simulate measurement (in a real quantum system, this would be a true quantum measurement)
            for i in range(self.num_qubits):
                # Change basis if needed
                if bob_bases[i] == 'diagonal':
                    H(qubits[i])
                
                # In a simulation, we'll use the original bit with some noise
                bit = self.alice_bits[i] if random.random() > 0.1 else 1 - self.alice_bits[i]
                self.bob_bits.append(bit)
            
            return qubits
        
        return bb84_circuit
    
    def sift_keys(self):
        """
        Sift the keys by comparing bases
        
        Returns:
            Tuple of matching keys for Alice and Bob
        """
        alice_sifted_key = []
        bob_sifted_key = []
        
        for i in range(self.num_qubits):
            if self.alice_bases[i] == self.bob_bases[i]:
                alice_sifted_key.append(self.alice_bits[i])
                bob_sifted_key.append(self.bob_bits[i])
        
        return alice_sifted_key, bob_sifted_key
    
    def run_protocol(self):
        """
        Execute the full BB84 protocol
        
        Returns:
            Tuple of results: (Alice's key, Bob's key, Matching percentage)
        """
        # Create the quantum circuit model
        bb84_model = self.create_bb84_circuit()
        
        # Synthesize the circuit
        circuit = synthesize(bb84_model)
        
        # Execute the circuit (this is a simulation)
        execute(circuit)
        
        # Sift keys (matching bases)
        alice_key, bob_key = self.sift_keys()
        
        # Calculate matching percentage
        matching_percentage = (
            sum(a == b for a, b in zip(alice_key, bob_key)) / 
            len(alice_key) * 100 if alice_key else 0
        )
        
        return alice_key, bob_key, matching_percentage

def main():
    # Run BB84 protocol
    protocol = BB84Protocol(num_qubits=20)
    alice_key, bob_key, matching_percentage = protocol.run_protocol()
    
    print("Alice's Bases:", protocol.alice_bases)
    print("Bob's Bases: ", protocol.bob_bases)
    print("\nAlice's Key:", alice_key)
    print("Bob's Key:  ", bob_key)
    print(f"\nKey Matching Percentage: {matching_percentage:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 137
#     134     print(f"\nKey Matching Percentage: {matching_percentage:.2f}%")
#     136 if __name__ == "__main__":
# --> 137     main()
#
# Cell In[13], line 128, in main()
#     125 def main():
#     126     # Run BB84 protocol
#     127     protocol = BB84Protocol(num_qubits=20)
# --> 128     alice_key, bob_key, matching_percentage = protocol.run_protocol()
#     130     print("Alice's Bases:", protocol.alice_bases)
#     131     print("Bob's Bases: ", protocol.bob_bases)
#
# Cell In[13], line 106, in BB84Protocol.run_protocol(self)
#      99 """
#     100 Execute the full BB84 protocol
#     101
#     102 Returns:
#     103     Tuple of results: (Alice's key, Bob's key, Matching percentage)
#     104 """
#     105 # Create the quantum circuit model
# --> 106 bb84_model = self.create_bb84_circuit()
#     108 # Synthesize the circuit
#     109 circuit = synthesize(bb84_model)
#
# Cell In[13], line 35, in BB84Protocol.create_bb84_circuit(self)
#      28 def create_bb84_circuit(self):
#      29     """
#      30     Create quantum circuit for BB84 protocol
#      31
#      32     Returns:
#      33         Quantum circuit model
#      34     """
# ---> 35     @create_model
#      36     def bb84_circuit(qubits: QArray[QBit]):
#      37         # Reset tracking lists
#      38         self.alice_bases.clear()
#      39         self.alice_bits.clear()
#
# File c:\Users\Aravind\college\quantum\venv\Lib\site-packages\classiq\qmod\create_model_function.py:40, in create_model(entry_point, constraints, execution_preferences, preferences, classical_execution_function, out_file)
#      14 def create_model(
#      15     entry_point: Union[QFunc, GenerativeQFunc],
#      16     constraints: Optional[Constraints] = None,
#    (...)
#      20     out_file: Optional[str] = None,
#      21 ) -> SerializedModel:
#      22     """
#      23     Create a serialized model from a given Qmod entry function and additional parameters.
#      24
#    (...)
#      37         ClassiqError: If the entry point function is not named 'main'.
#      38     """
# ---> 40     if entry_point.func_decl.name != MAIN_FUNCTION_NAME:
#      41         raise ClassiqError(
#      42             f"The entry point function must be named 'main', got '{entry_point.func_decl.name}'"
#      43         )
#      45     model = entry_point.create_model(
#      46         constraints,
#      47         execution_preferences,
#      48         preferences,
#      49         classical_execution_function,
#      50     )
#
# AttributeError: 'function' object has no attribute 'func_decl'

# %%
from classiq import ModelBuilder
import numpy as np

# Number of qubits (key length)
n = 10  # Change as needed

# Step 1: Alice generates random bits and bases
alice_bits = np.random.randint(2, size=n)  # 0s and 1s
alice_bases = np.random.randint(2, size=n)  # 0: Standard basis | 1: Hadamard basis

# Step 2: Define the quantum circuit using Classiq
builder = ModelBuilder()
qubits = builder.add_qubits(n)

# Alice prepares qubits based on bits and bases
for i in range(n):
    if alice_bits[i] == 1:
        builder.apply_gate("X", qubits[i])  # Encode bit as |1>
    if alice_bases[i] == 1:
        builder.apply_gate("H", qubits[i])  # Apply H if in Hadamard basis

# Step 3: Bob selects random bases for measurement
bob_bases = np.random.randint(2, size=n)
for i in range(n):
    if bob_bases[i] == 1:
        builder.apply_gate("H", qubits[i])  # Convert to standard basis if Hadamard
    builder.measure(qubits[i])

# Compile the quantum model
builder.compile()

# Step 4: Basis reconciliation (Key Sifting)
matching_bases = alice_bases == bob_bases
sifted_key = alice_bits[matching_bases]

# Step 5: Eavesdropping detection (Comparing a subset)
sample_size = max(1, len(sifted_key) // 4)  # Take 25% as sample
sample_indices = np.random.choice(len(sifted_key), sample_size, replace=False)
sample_bits = sifted_key[sample_indices]

# Alice and Bob verify sample bits to detect eavesdropping
if np.any(sample_bits != sifted_key[sample_indices]):
    print("Eavesdropper detected! Key discarded.")
else:
    print("Key is secure. Final key:", sifted_key)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from classiq import ModelBuilder
#       2 import numpy as np
#       4 # Number of qubits (key length)
#
# ImportError: cannot import name 'ModelBuilder' from 'classiq' (c:\Users\Aravind\college\quantum\venv\Lib\site-packages\classiq\__init__.py)
